# %%
import glob
path = "/home/malapati/Storage/diffusion-fc2/AlexNet/images/0"

images = sorted(glob.glob("/home/malapati/Storage/diffusion-fc2/AlexNet/images/0/*"))
f = open("/home/malapati/Storage/diffusion-fc2/AlexNet/images.list", "w")
print(len(images))
for file in images:

  #files = sorted(glob.glob(image+"/*"))
  #for file in files:
    line = "0"+ " " + path  + "/" + file.split("/")[-1]
    print(line)
    f.write(line+"\n")

f.close()
# Out:
# 2000
# 0 /home/malapati/Storage/diffusion-fc2/AlexNet/images/0/cat1.jpeg
# 0 /home/malapati/Storage/diffusion-fc2/AlexNet/images/0/cat10.jpeg
# 0 /home/malapati/Storage/diffusion-fc2/AlexNet/images/0/cat100.jpeg
# 0 /home/malapati/Storage/diffusion-fc2/AlexNet/images/0/cat1000.jpeg
# 0 /home/malapati/Storage/diffusion-fc2/AlexNet/images/0/cat101.jpeg
# 0 /home/malapati/Storage/diffusion-fc2/AlexNet/images/0/cat102.jpeg
# 0 /home/malapati/Storage/diffusion-fc2/AlexNet/images/0/cat103.jpeg
# 0 /home/malapati/Storage/diffusion-fc2/AlexNet/images/0/cat104.jpeg
# 0 /home/malapati/Storage/diffusion-fc2/AlexNet/images/0/cat105.jpeg
# 0 /home/malapati/Storage/diffusion-fc2/AlexNet/images/0/cat106.jpeg
# 0 /home/malapati/Storage/diffusion-fc2/AlexNet/images/0/cat107.jpeg
# 0 /home/malapati/Storage/diffusion-fc2/AlexNet/images/0/cat108.jpeg
# 0 /home/malapati/Storage/diffusion-fc2/AlexNet/images/0/cat109.jpeg
# 0 /home/malapati/Storage/diffusion-fc2/AlexNet/images/0/cat11.jpeg
# ...
